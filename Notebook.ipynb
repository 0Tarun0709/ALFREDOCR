# %%
import easyocr
reader = easyocr.Reader(['ch_sim','en']) # this needs to run only once to load the model into memory
result = reader.readtext(r"C:\Users\z0052mvs\Downloads\TarunDat\Revisit\ALFREDOCR\images\download.png")

# print(result)
for i in range(len(result)):
    print(result[i][1],end=" ")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# c:\Users\z0052mvs\Downloads\TarunDat\Revisit\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Imdge To TCxt Converter

# %%
text=''
for i in range(len(result)):
    text=text + result[i][1]
text
# Out:
# 'Imdge ToTCxt Converter'

# %%
for i in range(len(result)):
    print(result[i][1],end=" ")
# Out:
# Imdge To TCxt Converter

# %% [markdown]
# ### STREAMLIT CONFIG

# %%
[theme]  
primaryColor = '#000028'  
backgroundColor = '#000028'  
secondaryBackgroundColor = '#009999'  
textColor = '#FFFFFF'  
font = 'sans serif' 
  
[server]  
# run Streamlit in headless mode (no browser)  
headless = true  
# set the port number to serve the app on  
port = 8503
# enable Cross-Origin Resource Sharing (CORS) if needed  
enableCORS=true  
enableXsrfProtection=false
  
[browser]  
# set the server address for the browser  
serverAddress = "localhost"  
# set the server port for the browser  
serverPort = 8503 
gatherUsageStats = false
  
[logger]  
# set the logging level (debug, info, warning, error, critical)  
level = "error"  

[global]
developmentMode = false
